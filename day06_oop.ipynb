# %%
#oops concept :in python everything is consider as objecct to reduce code complexity .it has class and mehtod.
#class is ablueprint like bank is class and object is it insatnce or real object like house map is a class and a house is a object

#suppose we want to represent student which have name,course and marks if we want to creat student haveng this trait we need to creat separte code for each c
#student so we make class of student having all this trai and later own each student is created according to requirement of traite


# class key word is use 


class student:
    pass


student1 = student() #student1 is a object created from student class constructor

print(student1)

# %%
# __init__ constructor is use to initilize the object when clas is created 

class fruit:
    def __init__(self,name,colour):
        self.name= name
        self.colour=colour

fruit1 = fruit("banana","yellow")
print(fruit1)

fruit1.name
# Out:
# ...
# 'banana'

# %%
#instance attribute
#they are the data that belongs to a particular object self shows current object


class Book:
    def __init__(self,title,authour,price):
        self.title=title #instance attribute
        self.authour=authour
        self.price=price



Book1 = Book("twostate","chetan bhagat",678)
Book1.title
# Out:
# 'twostate'

# %%
#class attribute:this is the variable of class and every object of calss can use this

class Fruit:
    colour = "red"

    def __init__(self,name,taste):
        self.name = name
        self.taste = taste

fruit1 = Fruit("cherry","sweet")
fruit2 = Fruit("apple","sour")

print(fruit1.colour) 
print(fruit2.colour) #for both fruitthe colur is same or they can access the variable colur as it is a class attribute

print(fruit1.name)
print(fruit2.name) #they give separate value as they are insatnce attribute variable of defined boject only
# Out:
# red
# red
# cherry
# apple

# %%
#insatance method:instance method is a function defined inside a class start with def keyword andthe first parameter shoud be self as it said the variable 
#of the refered object


class Program:

    def __init__(self,name,duration):
        self.name= name
        self.duration = duration


    def info(self,complexity): #instance method
        print(self.name)
        
        print(complexity)
        print(self.duration)


Program1 = Program("java",3)

Program1.info("medium")
# Out:
# java
# medium
# 3

# %%
#class method :it works with class itself

#we use @clasmehod decorator for this
class Student:
    school = "Global College"

    @classmethod
    def show_school(cls):
        print("School:", cls.school)


Student.show_school()
# Out:
# School: Global College

# %%
#static method :this is method inside calss when denoted by @static it doesnot require self 


class Number:
    def __init__(self,x,y):
        self.x=x
        
        self.y=y
   
    @staticmethod

    
    def sum(x,y):
        print(x+y)

print(Number.sum(2,3)) #we can directly call staticmethod from class
# Out:
# 5

# %%
#
class Num:
    @staticmethod
    def is_even(x):
        return x%2==0



print(Num.is_even(12))
# Out:
# True

# %%
#encapsulation:they are use to hide data we use__varible name that need to be hide 




class Student:
    def __init__(self, name, marks):
        self.name = name
        self.__marks = marks

    def showmarks(self):
        print("Marks:", self.__marks)

    def update_marks(self, marks):
        if 0 <= marks <= 100:
            self.__marks = marks
        else:
            print("Invalid marks")


Student1 = Student("Ram", 100)

Student1.showmarks()

Student1.update_marks(90)
Student1.showmarks()
# Out:
# Marks: 100
# Marks: 90

# %% [markdown]
# Create a Bank Management System.
# Include:
# • Customer class
# • Account class
# • Deposit
# • Withdrawal
# • Balance checking
# • Transaction history
# Deliverable
# Demonstrate proper use of classes, objects and methods.

# %%
#bank management system

# Customer Class

class Customer:
    def __init__(self, customer_id, name, phone):
        self.customer_id = customer_id
        self.name = name
        self.phone = phone

    def info(self):
        print("Customer ID:", self.customer_id)
        print("Name:", self.name)
        print("Phone:", self.phone)


# Account Class

class Account:
    def __init__(self, account_number, account_type, balance):
        self.account_number = account_number
        self.account_type = account_type
        self.__balance = balance

    def account_info(self):
        print("Account Number:", self.account_number)
        print("Account Type:", self.account_type)
        print("Balance:", self.__balance)

    def deposit(self, amount):
        if amount > 0:
            self.__balance = self.__balance + amount
            print("Deposit successful")
        else:
            print("Invalid amount")

    def withdraw(self, amount):
        if amount > 0:
            if amount <= self.__balance:
                self.__balance = self.__balance - amount
                print("Withdrawal successful")
            else:
                print("Insufficient balance")
        else:
            print("Invalid amount")

    def check_balance(self):
        print("Balance:", self.__balance)


# Create Customers

customer1 = Customer(123, "Ram", "1234567897")
customer2 = Customer(345, "Sita", "2345678765")


# Display Customer Information

customer1.info()
print()

customer2.info()
print()


# Create Accounts

account1 = Account(1001, "Savings", 5000)
account2 = Account(1002, "Current", 10000)


# Display Account Information

account1.account_info()
print()


# Deposit

account1.deposit(2000)

# Withdraw

account1.withdraw(1000)

# Check Balance

account1.check_balance()
# Out:
# Customer ID: 123
# Name: Ram
# Phone: 1234567897
#
# Customer ID: 345
# Name: Sita
# Phone: 2345678765
#
# Account Number: 1001
# Account Type: Savings
# Balance: 5000
#
# Deposit successful
# Withdrawal successful
# Balance: 6000
